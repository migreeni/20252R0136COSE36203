# %%
import os
# os.environ['GUARDIAN_API_KEY'] = "YOUR_API_KEY_HERE"
# os.environ['GUARDIAN_API_KEY'] = 'cfc29433-1765-41ac-8726-14d5ce438b9d' #원준
os.environ['GUARDIAN_API_KEY'] = '77465cf2-e74d-4260-b796-7a9d2c829333' #규주

# %%
# ===== Cell 1: Setup & Config =====

import os, re, json, time, pathlib
from datetime import datetime, date
from typing import Dict, List, Tuple, Iterable
import requests
import pandas as pd

API_KEY = os.getenv("GUARDIAN_API_KEY", "").strip()
assert API_KEY, "Set GUARDIAN_API_KEY environment variable."

BASE_SEARCH = "https://content.guardianapis.com/search"
OUTPUT_COLS = [
    "id","webPublicationDate","headline","trailText","bodyText",
    "webTitle","webUrl","apiUrl","wordcount"
]

def slugify(s: str) -> str:
    """파일명으로 사용 가능한 slug 생성"""
    s = re.sub(r'[^0-9A-Za-z]+', '_', s.lower()).strip('_')
    return s or "query"

def year_slices(start_date: str, end_date: str) -> List[Tuple[int, str, str]]:
    """날짜 범위를 연도별로 분할"""
    sd = datetime.strptime(start_date, "%Y-%m-%d").date()
    ed = datetime.strptime(end_date, "%Y-%m-%d").date()
    assert sd <= ed, "start_date must be <= end_date"
    out = []
    y = sd.year
    while y <= ed.year:
        s = max(sd, date(y,1,1))
        e = min(ed, date(y,12,31))
        out.append((y, s.isoformat(), e.isoformat()))
        y += 1
    return out

def guardian_get(params: Dict, max_retries: int = 6) -> Dict:
    """Guardian API 호출 (에러 시 자동 재시도)"""
    p = dict(params)
    p["api-key"] = API_KEY
    sleep = 1.5
    for _ in range(max_retries):
        r = requests.get(BASE_SEARCH, params=p, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 502, 503, 504):
            time.sleep(sleep)
            sleep *= 2
            continue
        r.raise_for_status()
    raise RuntimeError(f"Guardian API failed: {r.status_code} {r.text[:200]}")

# %%
# ===== Cell 2: Fetch & Save Functions =====

def iter_results(q: str, from_date: str, to_date: str,
                 query_fields=("headline","body"), page_size: int = 200) -> Iterable[Dict]:
    """모든 페이지의 검색 결과를 yield"""
    params = {
        "q": q.lower(),
        "from-date": from_date,
        "to-date": to_date,
        "page-size": page_size,
        "order-by": "newest",
        "use-date": "published",
        "query-fields": ",".join(query_fields),
        "show-fields": "headline,trailText,bodyText,thumbnail,wordcount",
        "show-tags": "all",
    }
    js = guardian_get(params)
    resp = js.get("response", {})
    pages = int(resp.get("pages", 0)) or 0
    
    for it in resp.get("results", []):
        yield it
    
    for p in range(2, pages + 1):
        params["page"] = p
        js = guardian_get(params)
        for it in js.get("response", {}).get("results", []):
            yield it

def to_row(it: Dict) -> Dict:
    """검색 결과를 출력 스키마로 변환"""
    f = it.get("fields") or {}
    return {
        "id": it.get("id"),
        "webPublicationDate": it.get("webPublicationDate"),
        "headline": f.get("headline"),
        "trailText": f.get("trailText"),
        "bodyText": f.get("bodyText"),
        "webTitle": it.get("webTitle"),
        "webUrl": it.get("webUrl"),
        "apiUrl": it.get("apiUrl"),
        "wordcount": f.get("wordcount"),
    }

def crawl_and_save(query: str, start_date: str, end_date: str,
                   out_dir: str = "guardian_raw_scraping",
                   query_fields=("headline","body")) -> None:
    """크롤링 후 JSONL, CSV 저장"""
    slug = slugify(query)
    base = pathlib.Path(out_dir)
    base.mkdir(parents=True, exist_ok=True)
    
    # 모든 연도의 결과 수집
    seen, rows = set(), []
    for y, y_start, y_end in year_slices(start_date, end_date):
        print(f"  [{query}] Crawling {y}: {y_start} ~ {y_end}")
        for it in iter_results(query, y_start, y_end, query_fields=query_fields):
            _id = it.get("id")
            if _id in seen:
                continue
            seen.add(_id)
            rows.append(to_row(it))

    # JSONL 저장
    jsonl_path = base / f"{slug}.jsonl"
    with jsonl_path.open("w", encoding="utf-8") as jf:
        for r in rows:
            jf.write(json.dumps(r, ensure_ascii=False) + "\n")

    print(f"  [{query}] Total rows={len(rows)}  JSONL={jsonl_path.name}")

# %%
# ===== Cell 3: Batch Crawl & Summary =====

def batch_crawl_and_summary(
    people: List[str],
    start_date: str = "2017-01-01",
    end_date: str = "2019-12-31",
    out_dir: str = "guardian_scraping",
    query_fields=("headline","body"),
    skip_existing: bool = True,
) -> Dict[str, pathlib.Path]:
    """여러 인물에 대해 크롤링 후 summary CSV 생성"""
    out_base = pathlib.Path(out_dir)
    out_base.mkdir(parents=True, exist_ok=True)
    
    summary_data = []
    
    for i, p in enumerate(people, 1):
        slug = slugify(p)
        jsonl_path = out_base / f"{slug}.jsonl"
        
        # 기존 파일 있으면 스킵
        if skip_existing and jsonl_path.exists():
            print(f"\n[{i}/{len(people)}] SKIP (exists): {p}")
        else:
            print(f"\n[{i}/{len(people)}] Crawling: {p}")
            crawl_and_save(
                query=p,
                start_date=start_date,
                end_date=end_date,
                out_dir=out_dir,
                query_fields=query_fields,
            )
        
        # 연도별 기사 수 집계
        count_2017, count_2018, count_2019, total_count = 0, 0, 0, 0
        if jsonl_path.exists():  # csv_path → jsonl_path로 변경
            try:
                # JSONL 파일에서 직접 읽기
                rows = []
                with jsonl_path.open("r", encoding="utf-8") as f:
                    for line in f:
                        rows.append(json.loads(line))
                
                df = pd.DataFrame(rows)
                total_count = len(df)
                df['year'] = pd.to_datetime(df['webPublicationDate']).dt.year
                count_2017 = len(df[df['year'] == 2017])
                count_2018 = len(df[df['year'] == 2018])
                count_2019 = len(df[df['year'] == 2019])
            except Exception as e:
                print(f"  Warning: Could not read {jsonl_path.name}: {e}")
        
        summary_data.append({
            "person": p,
            "slug": slug,
            "2017": count_2017,
            "2018": count_2018,
            "2019": count_2019,
            "total": total_count,
        })

    # Summary CSV 저장
    df_summary = pd.DataFrame(summary_data)
    summary_path = "guardian_raw_scraping_summary.csv"
    df_summary.to_csv(summary_path, index=False, encoding="utf-8-sig")

    print(f"\n\nSaved summary: {summary_path}")
    print(f"Total people crawled: {len(people)}")
    print(f"Total articles: {df_summary['total'].sum()}")
    print(f"  - 2017: {df_summary['2017'].sum()}")
    print(f"  - 2018: {df_summary['2018'].sum()}")
    print(f"  - 2019: {df_summary['2019'].sum()}")

    return {"summary": summary_path}

# %%
# ===== Cell 4: Run =====

# people_list.txt 파일 읽기
with open('people_list.txt', 'r', encoding='utf-8') as f:
    content = f.read()

people_list = content.split('\n')
people_list = [name.strip() for name in people_list if name.strip()]

# 중복 체크
duplicates = [name for name in set(people_list) if people_list.count(name) > 1]
people = list(set(people_list))

print(f"Total: {len(people_list)} names")
print(f"Unique: {len(people)} people")
print(f"Duplicates: {len(people_list) - len(people)}")
if duplicates:
    print(f"Duplicate names: {duplicates}")
print(f"\nCrawling list: {people}")
print()

#people = ["Samantha Bee","Constance Wu"]
# 크롤링 실행
paths = batch_crawl_and_summary(
    people=people,
    start_date="2017-01-01",
    end_date="2019-12-31",
    out_dir="guardian_raw_scraping",
)
# Out:
# Total: 299 names
# Unique: 288 people
# Duplicates: 11
# Duplicate names: ['Kim Jong Un', 'Jeff Bezos', 'Jacinda Ardern', 'LeBron James', 'Donald Trump', 'Nancy Pelosi', 'Xi Jinping', 'Robert Mueller', 'Pope Francis']
#
# Crawling list: ['Sonia Friedman', 'Jair Bolsonaro', 'Deepika Padukone', 'Jose Andres', 'Julian Assange', 'Margrethe Vestager', 'Tarana Burke', 'Tom Brady', 'Ava DuVernay', 'Carmen Yulin Cruz', 'Mahathir Mohamad', 'David Hockney', 'Desmond Meade', 'Cindy Sherman', 'Margaret Atwood', 'Chloe Kim', 'Mohammed bin Salman', 'Haider al Abadi', 'Moon Jae in', 'Donald Glover', 'Emma Gonzalez', 'Michelle Obama', 'RuPaul', 'Indya Moore', 'Samin Nosrat', 'Emmanuel Macron', 'John Legend', 'John Lewis', 'Hamdi Ulukaya', 'Leila de Lima', 'Evan Spiegel', 'Ezra Levin', 'Daniel Ek', 'Greta Thunberg', 'Lena Waithe', 'Ailbhe Smyth', 'Vladimir Putin', 'Virat Kohli', 'David Adjaye', 'Millie Bobby Brown', 'Rodrigo Duterte', 'Kehinde Wiley', 'Glenn Close', 'Judy Chicago', 'Gal Gadot', 'Alicia Keys', 'Hasan Minhaj', 'Christopher Wylie', 'Margot Robbie', 'Viola Davis', 'Jared Kushner', 'Jason Blum', 'James Monsees', 'Shep Doeleman', 'Tara Westover', 'Recep Tayyip Erdogan', 'Jaclyn Corin', 'Jennifer Hyman', 'Leana Wen', 'Demis Hassabis', 'Shinzo Abe', 'Kim Jong Un', 'Sheikh Hasina', 'Colin Kaepernick', 'Peggy Whitson', 'Mauricio Macri', 'Kevin Kwan', 'Jeff Bezos', 'Chadwick Boseman', 'Luchita Hurtado', 'Virgil Abloh', 'Prince Harry', 'Qasem Soleimani', 'Hugh Jackman', 'James Corden', 'Marlon James', 'Chance the Rapper', 'Ann McKee', 'Jodi Kantor', 'Carmen Perez', 'Jacinda Ardern', 'Marica Branchesi', 'Megan Twohey', 'Sandra Day OConnor', 'Adam Neumann', 'Jesmyn Ward', 'Trevor Noah', 'Benjamin Netanyahu', 'Christine Blasey Ford', 'Theresa May', 'Theo Epstein', 'LeBron James', 'Glenda Gray', 'Vera Jourova', 'Ryan Reynolds', 'Ryan Murphy', 'Bhavish Aggarwal', 'Linda Sarsour', 'He Jiankui', 'Donald Trump', 'Samantha Bee', 'Ed Sheeran', 'Oprah Winfrey', 'Jerome Powell', 'Cameron Kasky', 'Greta Gerwig', 'Mohamed Salah', 'Savannah Guthrie', 'Bob Bland', 'Wang Qishan', 'Caster Semenya', 'David Hogg', 'Ren Zhengfei', 'Leo Varadkar', 'Rihanna', 'Rachael Denhollander', 'Justin Trudeau', 'Masayoshi Son', 'Jeff Sessions', 'Nancy Pelosi', 'Fatou Bensouda', 'Clare Waight Keller', 'Grainne Griffin', 'Brett Kavanaugh', 'Alexandria Ocasio-Cortez', 'Cardi B', 'Satya Nadella', 'Sterling Brown', 'JJ Watt', 'Adam Rippon', 'Xi Jinping', 'Chrissy Teigen', 'Ninja Blevins', 'Conor McGregor', 'James Comey', 'Chip Gaines', 'Tiffany Haddish', 'Cristina Jimenez', 'Nicole Kidman', 'Emily Comer', 'Tamika Mallory', 'Vijay Shekhar Sharma', 'Taylor Swift', 'Pierpaolo Piccioli', 'Michael Gillon', 'Jean Liu', 'Reince Priebus', 'Sinta Nuriyah', 'Hoda Kotb', 'Kirsten Green', 'Maxine Waters', 'Barry Jenkins', 'Carl June', 'Zhang Kejian', 'Alessandro Michele', 'Stephen Bannon', 'Ariana Grande', 'Issa Rae', 'BTS', 'Alex Wind', 'Leah Greenberg', 'Roseanne Barr', 'Jeanette Vizguerra', 'Ozuna', 'Biram Dah Abeid', 'Abiy Ahmed', 'Yuriko Koike', 'Kevin Durant', 'Guus Velders', 'Janet Yellen', 'Ashley Graham', 'Jay ONeal', 'Emmerson Mnangagwa', 'Elizabeth Diller', 'JR artist', 'Emma Stone', 'Hoesung Lee', 'Imran Khan', 'George Church', 'Mahershala Ali', 'Massimo Bottura', 'Emilia Clarke', 'Robert Mueller', 'Tiger Woods', 'General James Mattis', 'Gayle King', 'Jan Rader', 'Bernard Tyson', 'Menaka Guruswamy', 'Neymar', 'Yalitza Aparicio', 'Zhang Yiming', 'Chuck Schumer', 'Loujain al Hathloul', 'Andres Manuel Lopez', 'Tom Perez', 'Whitney Wolfe Herd', 'Sandra Oh', 'Guillermo del Toro', 'Thelma Aldana', 'Ben Platt', 'Scott Pruitt', 'Christian Siriano', 'Demi Lovato', 'Adam Bowen', 'Meghan Markle', 'Ruth Davidson', 'Sean Hannity', 'Kenneth Frazier', 'Elon Musk', 'Lady Gaga', 'Elizabeth Warren', 'Sadiq Khan', 'Pony Ma', 'Riz Ahmed', 'Gavin Grimm', 'Rami Malek', 'Joanna Gaines', 'Ivanka Trump', 'Guillem Anglada Escude', 'Brie Larson', 'Jian Wei Pan', 'Radhya Almutawakel', 'Shawn Mendes', 'Janet Mock', 'Roger Federer', 'Constance Wu', 'Celina Turchi', 'Pat McGrath', 'Jeanne Gang', 'Orla OConnor', 'Jimmy Kimmel', 'Marillyn Hewson', 'Richard Madden', 'Jordan Peele', 'Giuliano Testa', 'Bob Ferguson', 'Juan Manuel ...
#
#
# [1/288] SKIP (exists): Sonia Friedman
#
# [2/288] SKIP (exists): Jair Bolsonaro
#
# [3/288] SKIP (exists): Deepika Padukone
#
# [4/288] SKIP (exists): Jose Andres
#
# [5/288] SKIP (exists): Julian Assange
#
# [6/288] SKIP (exists): Margrethe Vestager
#
# [7/288] SKIP (exists): Tarana Burke
#
# [8/288] SKIP (exists): Tom Brady
#
# [9/288] SKIP (exists): Ava DuVernay
#
# [10/288] SKIP (exists): Carmen Yulin Cruz
#
# [11/288] SKIP (exists): Mahathir Mohamad
#
# [12/288] SKIP (exists): David Hockney
#
# [13/288] SKIP (exists): Desmond Meade
#
# [14/288] SKIP (exists): Cindy Sherman
#
# [15/288] SKIP (exists): Margaret Atwood
#
# [16/288] SKIP (exists): Chloe Kim
#
# [17/288] SKIP (exists): Mohammed bin Salman
#
# [18/288] SKIP (exists): Haider al Abadi
#
# [19/288] SKIP (exists): Moon Jae in
#
# [20/288] SKIP (exists): Donald Glover
#
# [21/288] SKIP (exists): Emma Gonzalez
#
# [22/288] SKIP (exists): Michelle Obama
#
# [23/288] SKIP (exists): RuPaul
#
# [24/288] SKIP (exists): Indya Moore
#
# [25/288] SKIP (exists): Samin Nosrat
#
# [26/288] SKIP (exists): Emmanuel Macron
#
# [27/288] SKIP (exists): John Legend
#
# [28/288] SKIP (exists): John Lewis
#
# [29/288] SKIP (exists): Hamdi Ulukaya
#
# [30/288] SKIP (exists): Leila de Lima
#
# [31/288] SKIP (exists): Evan Spiegel
#
# [32/288] SKIP (exists): Ezra Levin
#
# [33/288] SKIP (exists): Daniel Ek
#
# [34/288] SKIP (exists): Greta Thunberg
#
# [35/288] SKIP (exists): Lena Waithe
#
# [36/288] SKIP (exists): Ailbhe Smyth
#
# [37/288] SKIP (exists): Vladimir Putin
#
# [38/288] SKIP (exists): Virat Kohli
#
# [39/288] SKIP (exists): David Adjaye
#
# [40/288] SKIP (exists): Millie Bobby Brown
#
# [41/288] SKIP (exists): Rodrigo Duterte
#
# [42/288] SKIP (exists): Kehinde Wiley
#
# [43/288] SKIP (exists): Glenn Close
#
# [44/288] SKIP (exists): Judy Chicago
#
# [45/288] SKIP (exists): Gal Gadot
#
# [46/288] SKIP (exists): Alicia Keys
#
# [47/288] SKIP (exists): Hasan Minhaj
#
# [48/288] SKIP (exists): Christopher Wylie
#
# [49/288] SKIP (exists): Margot Robbie
#
# [50/288] SKIP (exists): Viola Davis
#
# [51/288] SKIP (exists): Jared Kushner
#
# [52/288] SKIP (exists): Jason Blum
#
# [53/288] SKIP (exists): James Monsees
#
# [54/288] SKIP (exists): Shep Doeleman
#
# [55/288] SKIP (exists): Tara Westover
#
# [56/288] SKIP (exists): Recep Tayyip Erdogan
#
# [57/288] SKIP (exists): Jaclyn Corin
#
# [58/288] SKIP (exists): Jennifer Hyman
#
# [59/288] SKIP (exists): Leana Wen
#
# [60/288] SKIP (exists): Demis Hassabis
#
# [61/288] SKIP (exists): Shinzo Abe
#
# [62/288] SKIP (exists): Kim Jong Un
#
# [63/288] SKIP (exists): Sheikh Hasina
#
# [64/288] SKIP (exists): Colin Kaepernick
#
# [65/288] SKIP (exists): Peggy Whitson
#
# [66/288] SKIP (exists): Mauricio Macri
#
# [67/288] SKIP (exists): Kevin Kwan
#
# [68/288] SKIP (exists): Jeff Bezos
#
# [69/288] SKIP (exists): Chadwick Boseman
#
# [70/288] SKIP (exists): Luchita Hurtado
#
# [71/288] SKIP (exists): Virgil Abloh
#
# [72/288] SKIP (exists): Prince Harry
#
# [73/288] SKIP (exists): Qasem Soleimani
#
# [74/288] SKIP (exists): Hugh Jackman
#
# [75/288] SKIP (exists): James Corden
#
# [76/288] SKIP (exists): Marlon James
#
# [77/288] SKIP (exists): Chance the Rapper
#
# [78/288] SKIP (exists): Ann McKee
#
# [79/288] SKIP (exists): Jodi Kantor
#
# [80/288] SKIP (exists): Carmen Perez
#
# [81/288] SKIP (exists): Jacinda Ardern
#
# [82/288] SKIP (exists): Marica Branchesi
#
# [83/288] SKIP (exists): Megan Twohey
#
# [84/288] SKIP (exists): Sandra Day OConnor
#
# [85/288] SKIP (exists): Adam Neumann
#
# [86/288] SKIP (exists): Jesmyn Ward
#
# [87/288] SKIP (exists): Trevor Noah
#
# [88/288] SKIP (exists): Benjamin Netanyahu
#
# [89/288] SKIP (exists): Christine Blasey Ford
#
# [90/288] SKIP (exists): Theresa May
#
# [91/288] SKIP (exists): Theo Epstein
#
# [92/288] SKIP (exists): LeBron James
#
# [93/288] SKIP (exists): Glenda Gray
#
# [94/288] SKIP (exists): Vera Jourova
#
# [95/288] SKIP (exists): Ryan Reynolds
#
# [96/288] SKIP (exists): Ryan Murphy
#
# [97/288] SKIP (exists): Bhavish Aggarwal
#
# [98/288] SKIP (exists): Linda Sarsour
#
# [99/288] SKIP (exists): He Jiankui
#
# [100/288] SKIP (exists): Donald Trump
#
# [101/288] SKIP (exists): Samantha Bee
#
# [102/288] SKIP (exists): Ed Sheeran
#
# [103/288] SKIP (exists): Oprah Winfrey
#
# [104/288] SKIP (exists): Jerome Powell
#
# [105/288] SKIP (exists): Cameron Kasky
#
# [106/288] SKIP (exists): Greta Gerwig
#
# [107/288] SKIP (exists): Mohamed Salah
#
# [108/288] SKIP (exists): Savannah Guthrie
#
# [109/288] SKIP (exists): Bob Bland
#
# [110/288] SKIP (exists): Wang Qishan
#
# [111/288] SKIP (exists): Caster Semenya
#
# [112/288] SKIP (exists): David Hogg
#
# [113/288] SKIP (exists): Ren Zhengfei
#
# [114/288] SKIP (exists): Leo Varadkar
#
# [115/288] SKIP (exists): Rihanna
#
# [116/288] SKIP (exists): Rachael Denhollander
#
# [117/288] SKIP (exists): Justin Trudeau
#
# [118/288] SKIP (exists): Masayoshi Son
#
# [119/288] SKIP (exists): Jeff Sessions
#
# [120/288] SKIP (exists): Nancy Pelosi
#
# [121/288] SKIP (exists): Fatou Bensouda
#
# [122/288] SKIP (exists): Clare Waight Keller
#
# [123/288] SKIP (exists): Grainne Griffin
#
# [124/288] SKIP (exists): Brett Kavanaugh
#
# [125/288] SKIP (exists): Alexandria Ocasio-Cortez
#
# [126/288] SKIP (exists): Cardi B
#
# [127/288] SKIP (exists): Satya Nadella
#
# [128/288] SKIP (exists): Sterling Brown
#
# [129/288] SKIP (exists): JJ Watt
#
# [130/288] SKIP (exists): Adam Rippon
#
# [131/288] SKIP (exists): Xi Jinping
#
# [132/288] SKIP (exists): Chrissy Teigen
#
# [133/288] SKIP (exists): Ninja Blevins
#
# [134/288] SKIP (exists): Conor McGregor
#
# [135/288] SKIP (exists): James Comey
#
# [136/288] SKIP (exists): Chip Gaines
#
# [137/288] SKIP (exists): Tiffany Haddish
#
# [138/288] SKIP (exists): Cristina Jimenez
#
# [139/288] SKIP (exists): Nicole Kidman
#
# [140/288] SKIP (exists): Emily Comer
#
# [141/288] SKIP (exists): Tamika Mallory
#
# [142/288] SKIP (exists): Vijay Shekhar Sharma
#
# [143/288] SKIP (exists): Taylor Swift
#
# [144/288] SKIP (exists): Pierpaolo Piccioli
#
# [145/288] SKIP (exists): Michael Gillon
#
# [146/288] SKIP (exists): Jean Liu
#
# [147/288] SKIP (exists): Reince Priebus
#
# [148/288] SKIP (exists): Sinta Nuriyah
#
# [149/288] SKIP (exists): Hoda Kotb
#
# [150/288] SKIP (exists): Kirsten Green
#
# [151/288] SKIP (exists): Maxine Waters
#
# [152/288] SKIP (exists): Barry Jenkins
#
# [153/288] SKIP (exists): Carl June
#
# [154/288] SKIP (exists): Zhang Kejian
#
# [155/288] SKIP (exists): Alessandro Michele
#
# [156/288] SKIP (exists): Stephen Bannon
#
# [157/288] SKIP (exists): Ariana Grande
#
# [158/288] SKIP (exists): Issa Rae
#
# [159/288] SKIP (exists): BTS
#
# [160/288] SKIP (exists): Alex Wind
#
# [161/288] SKIP (exists): Leah Greenberg
#
# [162/288] SKIP (exists): Roseanne Barr
#
# [163/288] SKIP (exists): Jeanette Vizguerra
#
# [164/288] SKIP (exists): Ozuna
#
# [165/288] SKIP (exists): Biram Dah Abeid
#
# [166/288] SKIP (exists): Abiy Ahmed
#
# [167/288] SKIP (exists): Yuriko Koike
#
# [168/288] SKIP (exists): Kevin Durant
#
# [169/288] SKIP (exists): Guus Velders
#
# [170/288] SKIP (exists): Janet Yellen
#
# [171/288] SKIP (exists): Ashley Graham
#
# [172/288] SKIP (exists): Jay ONeal
#
# [173/288] SKIP (exists): Emmerson Mnangagwa
#
# [174/288] SKIP (exists): Elizabeth Diller
#
# [175/288] SKIP (exists): JR artist
#
# [176/288] SKIP (exists): Emma Stone
#
# [177/288] SKIP (exists): Hoesung Lee
#
# [178/288] SKIP (exists): Imran Khan
#
# [179/288] SKIP (exists): George Church
#
# [180/288] SKIP (exists): Mahershala Ali
#
# [181/288] SKIP (exists): Massimo Bottura
#
# [182/288] SKIP (exists): Emilia Clarke
#
# [183/288] SKIP (exists): Robert Mueller
#
# [184/288] SKIP (exists): Tiger Woods
#
# [185/288] SKIP (exists): General James Mattis
#
# [186/288] SKIP (exists): Gayle King
#
# [187/288] SKIP (exists): Jan Rader
#
# [188/288] SKIP (exists): Bernard Tyson
#
# [189/288] SKIP (exists): Menaka Guruswamy
#
# [190/288] SKIP (exists): Neymar
#
# [191/288] SKIP (exists): Yalitza Aparicio
#
# [192/288] SKIP (exists): Zhang Yiming
#
# [193/288] SKIP (exists): Chuck Schumer
#
# [194/288] SKIP (exists): Loujain al Hathloul
#
# [195/288] SKIP (exists): Andres Manuel Lopez
#
# [196/288] SKIP (exists): Tom Perez
#
# [197/288] SKIP (exists): Whitney Wolfe Herd
#
# [198/288] SKIP (exists): Sandra Oh
#
# [199/288] SKIP (exists): Guillermo del Toro
#
# [200/288] SKIP (exists): Thelma Aldana
#
# [201/288] SKIP (exists): Ben Platt
#
# [202/288] SKIP (exists): Scott Pruitt
#
# [203/288] SKIP (exists): Christian Siriano
#
# [204/288] SKIP (exists): Demi Lovato
#
# [205/288] SKIP (exists): Adam Bowen
#
# [206/288] SKIP (exists): Meghan Markle
#
# [207/288] SKIP (exists): Ruth Davidson
#
# [208/288] SKIP (exists): Sean Hannity
#
# [209/288] SKIP (exists): Kenneth Frazier
#
# [210/288] SKIP (exists): Elon Musk
#
# [211/288] SKIP (exists): Lady Gaga
#
# [212/288] SKIP (exists): Elizabeth Warren
#
# [213/288] SKIP (exists): Sadiq Khan
#
# [214/288] SKIP (exists): Pony Ma
#
# [215/288] SKIP (exists): Riz Ahmed
#
# [216/288] SKIP (exists): Gavin Grimm
#
# [217/288] SKIP (exists): Rami Malek
#
# [218/288] SKIP (exists): Joanna Gaines
#
# [219/288] SKIP (exists): Ivanka Trump
#
# [220/288] SKIP (exists): Guillem Anglada Escude
#
# [221/288] SKIP (exists): Brie Larson
#
# [222/288] SKIP (exists): Jian Wei Pan
#
# [223/288] SKIP (exists): Radhya Almutawakel
#
# [224/288] SKIP (exists): Shawn Mendes
#
# [225/288] SKIP (exists): Janet Mock
#
# [226/288] SKIP (exists): Roger Federer
#
# [227/288] SKIP (exists): Constance Wu
#
# [228/288] SKIP (exists): Celina Turchi
#
# [229/288] SKIP (exists): Pat McGrath
#
# [230/288] SKIP (exists): Jeanne Gang
#
# [231/288] SKIP (exists): Orla OConnor
#
# [232/288] SKIP (exists): Jimmy Kimmel
#
# [233/288] SKIP (exists): Marillyn Hewson
#
# [234/288] SKIP (exists): Richard Madden
#
# [235/288] SKIP (exists): Jordan Peele
#
# [236/288] SKIP (exists): Giuliano Testa
#
# [237/288] SKIP (exists): Bob Ferguson
#
# [238/288] SKIP (exists): Juan Manuel Santos
#
# [239/288] SKIP (exists): Pope Francis
#
# [240/288] SKIP (exists): Mohamed bin Zayed
#
# [241/288] SKIP (exists): King Maha Vajiralongkorn
#
# [242/288] SKIP (exists): Regina King
#
# [243/288] SKIP (exists): Barbara Rae-Venter
#
# [244/288] SKIP (exists): Matteo Salvini
#
# [245/288] SKIP (exists): Maria Ressa
#
# [246/288] SKIP (exists): Narendra Modi
#
# [247/288] SKIP (exists): John Krasinski
#
# [248/288] SKIP (exists): dream hampton
#
# [249/288] SKIP (exists): Ronan Farrow
#
# [250/288] SKIP (exists): Simone Biles
#
# [251/288] SKIP (exists): Cindy Holland
#
# [252/288] SKIP (exists): Natalie Batalha
#
# [253/288] SKIP (exists): Gretchen Carlson
#
# [254/288] SKIP (exists): Jane Goodall
#
# [255/288] SKIP (exists): Arundhati Katju
#
# [256/288] SKIP (exists): Khalid
#
# [257/288] SKIP (exists): Spike Lee
#
# [258/288] SKIP (exists): Mirian G
#
# [259/288] SKIP (exists): Kerry James Marshall
#
# [260/288] SKIP (exists): Mark Zuckerberg
#
# [261/288] SKIP (exists): Alex Morgan
#
# [262/288] SKIP (exists): Juan Guaido
#
# [263/288] SKIP (exists): Fan Bingbing
#
# [264/288] SKIP (exists): Arlette Contreras
#
# [265/288] SKIP (exists): Aileen Lee
#
# [266/288] SKIP (exists): Bob Iger
#
# [267/288] SKIP (exists): Kesha
#
# [268/288] SKIP (exists): Barbara Lynch
#
# [269/288] SKIP (exists): James Allison
#
# [270/288] SKIP (exists): Jennifer Lopez
#
# [271/288] SKIP (exists): Dwayne Johnson
#
# [272/288] SKIP (exists): Raed Saleh
#
# [273/288] SKIP (exists): Nice Nailantei Lengete
#
# [274/288] SKIP (exists): Naomi Osaka
#
# [275/288] SKIP (exists): Colson Whitehead
#
# [276/288] SKIP (exists): Daniela Vega
#
# [277/288] SKIP (exists): Mukesh Ambani
#
# [278/288] SKIP (exists): Ryan Coogler
#
# [279/288] SKIP (exists): Lynn Nottage
#
# [280/288] SKIP (exists): Mitch McConnell
#
# [281/288] SKIP (exists): Rebekah Mercer
#
# [282/288] SKIP (exists): Kumail Nanjiani
#
# [283/288] SKIP (exists): Fred Swaniker
#
# [284/288] SKIP (exists): Cyril Ramaphosa
#
# [285/288] SKIP (exists): Raf Simons
#
# [286/288] SKIP (exists): William Barr
#
# [287/288] SKIP (exists): Leslie Jones
#
# [288/288] SKIP (exists): Sarah Paulson
#
#
# Saved summary: guardian_raw_scraping_summary.csv
# Total people crawled: 288
# Total articles: 608130
#   - 2017: 211599
#   - 2018: 196426
#   - 2019: 200105

# %% [markdown]
# # Only top100

# %%
# ===== Cell 5: Extract Top 100 & Copy Files =====

import pandas as pd
import shutil
import os

# guardian_raw_scraping_summary.csv 읽기
df = pd.read_csv('guardian_raw_scraping_summary.csv')

# total 기준 내림차순 정렬 후 top 100 추출
df_sorted = df.sort_values('total', ascending=False).head(100)
top100_people = df_sorted['person'].tolist()

print(f"Top 100 people by total articles: {len(top100_people)}")
print(f"Total articles: {df_sorted['total'].sum()}")
print(f"\nTop 10:")
print(df_sorted[['person', 'total']].head(10).to_string(index=False))

# people_top100_list.txt 저장
with open('people_top100_list.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(top100_people))
print(f"\nSaved: people_top100_list.txt")

# guardian_top100_scraping 폴더 생성
new_dir = 'guardian_top100_scraping'
os.makedirs(new_dir, exist_ok=True)

# jsonl 파일 복사
copied_count = 0
for person in top100_people:
    slug = df_sorted[df_sorted['person'] == person]['slug'].values[0]
    src_file = f'guardian_raw_scraping/{slug}.jsonl'
    dst_file = f'{new_dir}/{slug}.jsonl'
    
    if os.path.exists(src_file):
        shutil.copy2(src_file, dst_file)
        copied_count += 1

print(f"\nCopied {copied_count} jsonl files to {new_dir}/")
# Out:
# Top 100 people by total articles: 100
# Total articles: 461270
#
# Top 10:
#           person  total
#     Donald Trump  26542
#      Theresa May  22188
#      Ryan Murphy  10453
#    Jeff Sessions   8688
# Elizabeth Warren   8476
#    Ryan Reynolds   8467
#     Ivanka Trump   8137
#     Ryan Coogler   7442
#     Prince Harry   6213
#      Kim Jong Un   6121
#
# Saved: people_top100_list.txt
#
# Copied 100 jsonl files to guardian_top100_scraping/

# %%
import os
import numpy as np
import json

# 검사할 상위 폴더들
gpu_dirs = [
    "vector_paragraphs_gpu0",
    "vector_paragraphs_gpu1",
    "vector_paragraphs_gpu2",
    "vector_paragraphs_gpu3",
]

def count_jsonl(path):
    with open(path, "r") as f:
        return sum(1 for _ in f)

def check_folder(folder):
    print(f"\n=== Checking folder: {folder} ===")

    files = os.listdir(folder)

    # basename 목록 생성 (예: alex_morgan)
    basenames = set()
    for f in files:
        if f.endswith("_embeddings.npy"):
            basenames.add(f.replace("_embeddings.npy", ""))
        if f.endswith("_metadata.jsonl"):
            basenames.add(f.replace("_metadata.jsonl", ""))

    for name in basenames:
        npy_path = os.path.join(folder, f"{name}_embeddings.npy")
        jsonl_path = os.path.join(folder, f"{name}_metadata.jsonl")

        if not os.path.exists(npy_path) or not os.path.exists(jsonl_path):
            print(f"[MISSING] {name}: one of the files is missing")
            continue

        # Load lengths
        npy_len = np.load(npy_path).shape[0]
        jsonl_len = count_jsonl(jsonl_path)

        if npy_len == jsonl_len:
            print(f"[OK] {name} -> npy={npy_len}, jsonl={jsonl_len}")
        else:
            print(f"[MISMATCH] {name} -> npy={npy_len}, jsonl={jsonl_len}")

# 전체 폴더 검사
for d in gpu_dirs:
    if os.path.exists(d):
        check_folder(d)
    else:
        print(f"Folder not found: {d}")
# Out:
# === Checking folder: vector_paragraphs_gpu0 ===
# [OK] kerry_james_marshall -> npy=3629, jsonl=3629
# [OK] donald_trump -> npy=26516, jsonl=26516
# [OK] guillermo_del_toro -> npy=2965, jsonl=2965
# [OK] barbara_rae_venter -> npy=2635, jsonl=2635
# [OK] julian_assange -> npy=4010, jsonl=4010
# [OK] ashley_graham -> npy=5068, jsonl=5068
# [OK] barbara_lynch -> npy=3256, jsonl=3256
# [OK] chip_gaines -> npy=3115, jsonl=3115
# [OK] alicia_keys -> npy=2544, jsonl=2544
# [OK] bernard_tyson -> npy=2711, jsonl=2711
# [OK] andres_manuel_lopez -> npy=3244, jsonl=3244
# [OK] juan_guaido -> npy=2652, jsonl=2652
# [OK] emilia_clarke -> npy=3856, jsonl=3856
# [OK] robert_mueller -> npy=2974, jsonl=2974
# [OK] ruth_davidson -> npy=3696, jsonl=3696
# [OK] john_legend -> npy=5281, jsonl=5281
# [OK] glenn_close -> npy=2644, jsonl=2644
# [OK] jian_wei_pan -> npy=3397, jsonl=3397
# [OK] justin_trudeau -> npy=4983, jsonl=4983
# [OK] chuck_schumer -> npy=2254, jsonl=2254
# [OK] glenda_gray -> npy=2277, jsonl=2277
# [OK] david_hogg -> npy=2043, jsonl=2043
# [OK] colin_kaepernick -> npy=3326, jsonl=3326
# [OK] bob_bland -> npy=3107, jsonl=3107
# [OK] jr_artist -> npy=3592, jsonl=3592
# [OK] judy_chicago -> npy=4164, jsonl=4164
# [OK] moon_jae_in -> npy=4308, jsonl=4308
# [OK] chloe_kim -> npy=5800, jsonl=5800
# [OK] mohammed_bin_salman -> npy=5596, jsonl=5596
# [OK] ann_mckee -> npy=2466, jsonl=2466
# [OK] christine_blasey_ford -> npy=5055, jsonl=5055
# [OK] bob_ferguson -> npy=3922, jsonl=3922
# [OK] kim_jong_un -> npy=6121, jsonl=6121
# [OK] john_lewis -> npy=4675, jsonl=4675
# [OK] he_jiankui -> npy=2504, jsonl=2504
# [OK] carl_june -> npy=2310, jsonl=2310
# [OK] benjamin_netanyahu -> npy=3247, jsonl=3247
# [OK] cindy_holland -> npy=2431, jsonl=2431
# [OK] emma_stone -> npy=5044, jsonl=5044
# [OK] nancy_pelosi -> npy=2392, jsonl=2392
# [OK] juan_manuel_santos -> npy=5050, jsonl=5050
# [OK] christopher_wylie -> npy=6043, jsonl=6043
# [OK] barry_jenkins -> npy=5999, jsonl=5999
# [OK] jordan_peele -> npy=5471, jsonl=5471
# [OK] emily_comer -> npy=3693, jsonl=3693
# [OK] roger_federer -> npy=4370, jsonl=4370
# [OK] pat_mcgrath -> npy=3366, jsonl=3366
# [OK] emmanuel_macron -> npy=3863, jsonl=3863
# [OK] pope_francis -> npy=4646, jsonl=4646
# [OK] jimmy_kimmel -> npy=3650, jsonl=3650
# [OK] emma_gonzalez -> npy=5232, jsonl=5232
# [OK] jose_andres -> npy=2786, jsonl=2786
# [OK] prince_harry -> npy=6205, jsonl=6205
# [OK] alex_morgan -> npy=5829, jsonl=5829
# [OK] chance_the_rapper -> npy=2790, jsonl=2790
# [OK] gavin_grimm -> npy=2417, jsonl=2417
# Folder not found: vector_paragraphs_gpu1
# Folder not found: vector_paragraphs_gpu2
# Folder not found: vector_paragraphs_gpu3

# %%
import os
import json
import shutil

gpu_dirs = [
    "vector_paragraphs_gpu0",
    "vector_paragraphs_gpu1",
    "vector_paragraphs_gpu2",
    "vector_paragraphs_gpu3",
]

target_dir = "vector_paragraphs_gpu0"

# -----------------------------
# 1. checkpoint.json 병합
# -----------------------------
merged_processed = set()

for d in gpu_dirs:
    ckpt_path = os.path.join(d, "checkpoint.json")
    if not os.path.exists(ckpt_path):
        print(f"[SKIP] {ckpt_path} 없음.")
        continue

    with open(ckpt_path, "r") as f:
        data = json.load(f)

    processed = data.get("processed_files", [])
    merged_processed.update(processed)
    print(f"[LOAD] {d}: {len(processed)} files")

# 정렬하여 병합 파일 생성
merged_list = sorted(list(merged_processed))
output_ckpt = os.path.join(target_dir, "checkpoint.json")

with open(output_ckpt, "w") as f:
    json.dump({"processed_files": merged_list}, f, indent=2)

print(f"\n[WRITE] 병합 checkpoint 저장 완료: {output_ckpt}")
print(f"총 파일 개수: {len(merged_list)}")

# -----------------------------
# 2. gpu1/2/3의 checkpoint.json 삭제
# -----------------------------
for d in gpu_dirs[1:]:
    ckpt_path = os.path.join(d, "checkpoint.json")
    if os.path.exists(ckpt_path):
        os.remove(ckpt_path)
        print(f"[DELETE] {ckpt_path} 삭제 완료")
    else:
        print(f"[SKIP] {ckpt_path} 없음")

# -----------------------------
# 3. gpu1/2/3의 모든 파일을 gpu0으로 이동
# -----------------------------
for d in gpu_dirs[1:]:
    for fname in os.listdir(d):
        src = os.path.join(d, fname)
        dst = os.path.join(target_dir, fname)

        # 충돌 방지를 위해 중복 파일이 있을 경우 이름 변경
        if os.path.exists(dst):
            base, ext = os.path.splitext(fname)
            new_name = f"{base}_from_{os.path.basename(d)}{ext}"
            dst = os.path.join(target_dir, new_name)
            print(f"[RENAME] {fname} → {new_name}")

        shutil.move(src, dst)
        print(f"[MOVE] {src} → {dst}")

    print(f"[CLEAR] {d} 폴더 파일 이동 완료")

print("\n[FINISHED] 모든 병합·삭제·이동 완료")
# Out:
# [LOAD] vector_paragraphs_gpu0: 15 files
# [LOAD] vector_paragraphs_gpu1: 10 files
# [LOAD] vector_paragraphs_gpu2: 14 files
# [LOAD] vector_paragraphs_gpu3: 9 files
#
# [WRITE] 병합 checkpoint 저장 완료: vector_paragraphs_gpu0/checkpoint.json
# 총 파일 개수: 48
# [DELETE] vector_paragraphs_gpu1/checkpoint.json 삭제 완료
# [DELETE] vector_paragraphs_gpu2/checkpoint.json 삭제 완료
# [DELETE] vector_paragraphs_gpu3/checkpoint.json 삭제 완료
# [MOVE] vector_paragraphs_gpu1/emilia_clarke_embeddings.npy → vector_paragraphs_gpu0/emilia_clarke_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/emilia_clarke_metadata.jsonl → vector_paragraphs_gpu0/emilia_clarke_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/emily_comer_embeddings.npy → vector_paragraphs_gpu0/emily_comer_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/emily_comer_metadata.jsonl → vector_paragraphs_gpu0/emily_comer_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/emma_gonzalez_embeddings.npy → vector_paragraphs_gpu0/emma_gonzalez_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/emma_gonzalez_metadata.jsonl → vector_paragraphs_gpu0/emma_gonzalez_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/emma_stone_embeddings.npy → vector_paragraphs_gpu0/emma_stone_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/emma_stone_metadata.jsonl → vector_paragraphs_gpu0/emma_stone_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/emmanuel_macron_embeddings.npy → vector_paragraphs_gpu0/emmanuel_macron_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/emmanuel_macron_metadata.jsonl → vector_paragraphs_gpu0/emmanuel_macron_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/gavin_grimm_embeddings.npy → vector_paragraphs_gpu0/gavin_grimm_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/gavin_grimm_metadata.jsonl → vector_paragraphs_gpu0/gavin_grimm_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/glenda_gray_embeddings.npy → vector_paragraphs_gpu0/glenda_gray_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/glenda_gray_metadata.jsonl → vector_paragraphs_gpu0/glenda_gray_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/glenn_close_embeddings.npy → vector_paragraphs_gpu0/glenn_close_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/glenn_close_metadata.jsonl → vector_paragraphs_gpu0/glenn_close_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/guillermo_del_toro_embeddings.npy → vector_paragraphs_gpu0/guillermo_del_toro_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/guillermo_del_toro_metadata.jsonl → vector_paragraphs_gpu0/guillermo_del_toro_metadata.jsonl
# [MOVE] vector_paragraphs_gpu1/he_jiankui_embeddings.npy → vector_paragraphs_gpu0/he_jiankui_embeddings.npy
# [MOVE] vector_paragraphs_gpu1/he_jiankui_metadata.jsonl → vector_paragraphs_gpu0/he_jiankui_metadata.jsonl
# [CLEAR] vector_paragraphs_gpu1 폴더 파일 이동 완료
# [MOVE] vector_paragraphs_gpu2/jian_wei_pan_embeddings.npy → vector_paragraphs_gpu0/jian_wei_pan_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/jian_wei_pan_metadata.jsonl → vector_paragraphs_gpu0/jian_wei_pan_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/jimmy_kimmel_embeddings.npy → vector_paragraphs_gpu0/jimmy_kimmel_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/jimmy_kimmel_metadata.jsonl → vector_paragraphs_gpu0/jimmy_kimmel_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/john_legend_embeddings.npy → vector_paragraphs_gpu0/john_legend_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/john_legend_metadata.jsonl → vector_paragraphs_gpu0/john_legend_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/john_lewis_embeddings.npy → vector_paragraphs_gpu0/john_lewis_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/john_lewis_metadata.jsonl → vector_paragraphs_gpu0/john_lewis_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/jordan_peele_embeddings.npy → vector_paragraphs_gpu0/jordan_peele_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/jordan_peele_metadata.jsonl → vector_paragraphs_gpu0/jordan_peele_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/jose_andres_embeddings.npy → vector_paragraphs_gpu0/jose_andres_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/jose_andres_metadata.jsonl → vector_paragraphs_gpu0/jose_andres_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/jr_artist_embeddings.npy → vector_paragraphs_gpu0/jr_artist_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/jr_artist_metadata.jsonl → vector_paragraphs_gpu0/jr_artist_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/juan_guaido_embeddings.npy → vector_paragraphs_gpu0/juan_guaido_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/juan_guaido_metadata.jsonl → vector_paragraphs_gpu0/juan_guaido_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/juan_manuel_santos_embeddings.npy → vector_paragraphs_gpu0/juan_manuel_santos_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/juan_manuel_santos_metadata.jsonl → vector_paragraphs_gpu0/juan_manuel_santos_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/judy_chicago_embeddings.npy → vector_paragraphs_gpu0/judy_chicago_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/judy_chicago_metadata.jsonl → vector_paragraphs_gpu0/judy_chicago_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/julian_assange_embeddings.npy → vector_paragraphs_gpu0/julian_assange_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/julian_assange_metadata.jsonl → vector_paragraphs_gpu0/julian_assange_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/justin_trudeau_embeddings.npy → vector_paragraphs_gpu0/justin_trudeau_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/justin_trudeau_metadata.jsonl → vector_paragraphs_gpu0/justin_trudeau_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/kerry_james_marshall_embeddings.npy → vector_paragraphs_gpu0/kerry_james_marshall_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/kerry_james_marshall_metadata.jsonl → vector_paragraphs_gpu0/kerry_james_marshall_metadata.jsonl
# [MOVE] vector_paragraphs_gpu2/kim_jong_un_embeddings.npy → vector_paragraphs_gpu0/kim_jong_un_embeddings.npy
# [MOVE] vector_paragraphs_gpu2/kim_jong_un_metadata.jsonl → vector_paragraphs_gpu0/kim_jong_un_metadata.jsonl
# [CLEAR] vector_paragraphs_gpu2 폴더 파일 이동 완료
# [MOVE] vector_paragraphs_gpu3/mohammed_bin_salman_embeddings.npy → vector_paragraphs_gpu0/mohammed_bin_salman_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/mohammed_bin_salman_metadata.jsonl → vector_paragraphs_gpu0/mohammed_bin_salman_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/moon_jae_in_embeddings.npy → vector_paragraphs_gpu0/moon_jae_in_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/moon_jae_in_metadata.jsonl → vector_paragraphs_gpu0/moon_jae_in_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/nancy_pelosi_embeddings.npy → vector_paragraphs_gpu0/nancy_pelosi_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/nancy_pelosi_metadata.jsonl → vector_paragraphs_gpu0/nancy_pelosi_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/pat_mcgrath_embeddings.npy → vector_paragraphs_gpu0/pat_mcgrath_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/pat_mcgrath_metadata.jsonl → vector_paragraphs_gpu0/pat_mcgrath_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/pope_francis_embeddings.npy → vector_paragraphs_gpu0/pope_francis_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/pope_francis_metadata.jsonl → vector_paragraphs_gpu0/pope_francis_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/prince_harry_embeddings.npy → vector_paragraphs_gpu0/prince_harry_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/prince_harry_metadata.jsonl → vector_paragraphs_gpu0/prince_harry_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/robert_mueller_embeddings.npy → vector_paragraphs_gpu0/robert_mueller_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/robert_mueller_metadata.jsonl → vector_paragraphs_gpu0/robert_mueller_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/roger_federer_embeddings.npy → vector_paragraphs_gpu0/roger_federer_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/roger_federer_metadata.jsonl → vector_paragraphs_gpu0/roger_federer_metadata.jsonl
# [MOVE] vector_paragraphs_gpu3/ruth_davidson_embeddings.npy → vector_paragraphs_gpu0/ruth_davidson_embeddings.npy
# [MOVE] vector_paragraphs_gpu3/ruth_davidson_metadata.jsonl → vector_paragraphs_gpu0/ruth_davidson_metadata.jsonl
# [CLEAR] vector_paragraphs_gpu3 폴더 파일 이동 완료
#
# [FINISHED] 모든 병합·삭제·이동 완료
